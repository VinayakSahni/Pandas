# %%
import pandas as pd

# %%
imdb_df=pd.read_csv(r"C:\Users\vinay\Documents\Python Scripts\exerices\Panda_Exerice\imdb_1000.csv")

# %%
imdb_df.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
bikes_df=pd.read_csv(r"C:\Users\vinay\Documents\Python Scripts\exerices\Panda_Exerice\bikes.csv")

# %%
bikes_df.head(3)
# Out:
#          Date Unnamed: 1  Rachel / Papineau  Berri1  Maisonneuve_2  \
# 0  01-01-2012      00:00                 16      35             51
# 1  02-01-2012      00:00                 43      83            153
# 2  03-01-2012      00:00                 58     135            248
#
#    Maisonneuve_1  Brébeuf  Parc  PierDup  CSC (Côte Sainte-Catherine)  \
# 0             38      5.0    26       10                            0
# 1             68     11.0    53        6                            1
# 2            104      2.0    89        3                            2
#
#    Pont_Jacques_Cartier
# 0                  27.0
# 1                  21.0
# 2                  15.0

# %%
imdb_df.columns
# Out:
# Index(['star_rating', 'title', 'content_rating', 'genre', 'duration',
#        'actors_list'],
#       dtype='object')

# %%
imdb_df.dtypes
# Out:
# star_rating       float64
# title              object
# content_rating     object
# genre              object
# duration            int64
# actors_list        object
# dtype: object

# %%
imdb_df['title'].head()
# Out:
# 0    The Shawshank Redemption
# 1               The Godfather
# 2      The Godfather: Part II
# 3             The Dark Knight
# 4                Pulp Fiction
# Name: title, dtype: object

# %%
imdb_df[['title','genre']].head()
# Out:
#                       title   genre
# 0  The Shawshank Redemption   Crime
# 1             The Godfather   Crime
# 2    The Godfather: Part II   Crime
# 3           The Dark Knight  Action
# 4              Pulp Fiction   Crime

# %%
imdb_df.duration.dtype
# Out:
# dtype('int64')

# %%
imdb_df.duration.values
# Out:
# array([142, 175, 200, 152, 154,  96, 161, 201, 195, 139, 178, 148, 124,
#        142, 179, 169, 133, 207, 146, 121, 136, 130, 130, 106, 127, 116,
#        175, 118, 110,  87, 125, 112, 102, 107, 119,  87, 169, 115, 112,
#        109, 189, 110, 150, 165, 155, 137, 113, 165,  95, 151, 155, 153,
#        125, 130, 116,  89, 137, 117,  88, 165, 170,  89, 146,  99,  98,
#        116, 156, 122, 149, 134, 122, 136, 157, 123, 119, 137, 128, 120,
#        229, 107, 134, 103, 177, 129, 102, 216, 136,  93,  68, 189,  99,
#        108, 113, 181, 103, 138, 110, 129,  88, 160, 126,  91, 116, 125,
#        143,  93, 102, 132, 153, 183, 160, 120, 138, 140, 153, 170, 129,
#         81, 127, 131, 172, 115, 108, 107, 129, 156,  96,  91,  95, 162,
#        130,  86, 186, 151,  96, 170, 118, 161, 131, 126, 131, 129, 224,
#        180, 105, 117, 140, 119, 124, 130, 139, 107, 132, 117, 126, 122,
#        178, 238, 149, 172,  98, 116, 116, 123, 148, 123, 182,  92,  93,
# ...

# %%
to_uppercase= lambda x: x.upper()
upeercase=imdb_df['title'].apply(to_uppercase).head()
upeercase
# Out:
# 0    THE SHAWSHANK REDEMPTION
# 1               THE GODFATHER
# 2      THE GODFATHER: PART II
# 3             THE DARK KNIGHT
# 4                PULP FICTION
# Name: title, dtype: object

# %%
import matplotlib.pyplot as plt
bikes_df['Berri1'].plot()
# Out:
# <AxesSubplot:>

# %%
bikes_df.plot(figsize=(10,10))
# Out:
# <AxesSubplot:>

# %%
imdb_df['genre'].value_counts()
# Out:
# Drama        278
# Comedy       156
# Action       136
# Crime        124
# Biography     77
# Adventure     75
# Animation     62
# Horror        29
# Mystery       16
# Western        9
# Sci-Fi         5
# Thriller       5
# Film-Noir      3
# Family         2
# Fantasy        1
# History        1
# Name: genre, dtype: int64

# %%
imdb_df['genre'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
imdb_df['genre'].value_counts().plot.pie()
# Out:
# <AxesSubplot:ylabel='genre'>

# %%
bikes_df.index
# Out:
# RangeIndex(start=0, stop=366, step=1)

# %%
bikes_df.iloc[0]
# Out:
# Date                           01-01-2012
# Unnamed: 1                          00:00
# Rachel / Papineau                      16
# Berri1                                 35
# Maisonneuve_2                          51
# Maisonneuve_1                          38
# Brébeuf                               5.0
# Parc                                   26
# PierDup                                10
# CSC (Côte Sainte-Catherine)             0
# Pont_Jacques_Cartier                 27.0
# Name: 0, dtype: object

# %%
imdb_df.iloc[10]
# Out:
# star_rating                                                     8.8
# title             The Lord of the Rings: The Fellowship of the Ring
# content_rating                                                PG-13
# genre                                                     Adventure
# duration                                                        178
# actors_list       [u'Elijah Wood', u'Ian McKellen', u'Orlando Bl...
# Name: 10, dtype: object

# %%
imdb_df[imdb_df['genre']=='Adventure'].head()
# Out:
#     star_rating                                              title  \
# 7           8.9      The Lord of the Rings: The Return of the King
# 10          8.8  The Lord of the Rings: The Fellowship of the Ring
# 14          8.8              The Lord of the Rings: The Two Towers
# 15          8.7                                       Interstellar
# 54          8.5                                 Back to the Future
#
#    content_rating      genre  duration  \
# 7           PG-13  Adventure       201
# 10          PG-13  Adventure       178
# 14          PG-13  Adventure       179
# 15          PG-13  Adventure       169
# 54             PG  Adventure       116
#
#                                           actors_list
# 7   [u'Elijah Wood', u'Viggo Mortensen', u'Ian McK...
# 10  [u'Elijah Wood', u'Ian McKellen', u'Orlando Bl...
# 14  [u'Elijah Wood', u'Ian McKellen', u'Viggo Mort...
# 15  [u'Matthew McConaughey', u'Anne Hathaway', u'J...
# ...

# %%
good_conditon=(imdb_df['star_rating']>8) & (imdb_df['duration']>130)
imdb_df[good_conditon]['genre'].value_counts()
# Out:
# Drama        36
# Action       20
# Adventure    17
# Crime        13
# Biography    12
# Comedy        6
# Western       6
# Mystery       3
# Animation     1
# Horror        1
# Name: genre, dtype: int64

# %%
imdb_df['weekday']=imdb_df.duration

# %%
imdb_df.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list  weekday
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...      142
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']      175
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...      200
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...      152
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....      154

# %%
bikes_df.drop('Unnamed: 1', axis=1, inplace=True)

# %%
bikes_df.drop(0,axis=0)
# Out:
#            Date  Rachel / Papineau  Berri1  Maisonneuve_2  Maisonneuve_1  \
# 1    02-01-2012                 43      83            153             68
# 2    03-01-2012                 58     135            248            104
# 3    04-01-2012                 61     144            318            116
# 4    05-01-2012                 95     197            330            124
# 5    06-01-2012                 75     146            244             98
# ..          ...                ...     ...            ...            ...
# 361  27-12-2012                  8      12              7              4
# 362  28-12-2012                  0      35              3             38
# 363  29-12-2012                  0      27              8             42
# 364  30-12-2012                  0       5              1              5
# 365  31-12-2012                  0       4              3              8
#
#      Brébeuf  Parc  PierDup  CSC (Côte Sainte-Catherine)  Pont_Jacques_Cartier
# ...

# %%
genre_group=imdb_df.groupby('genre')

# %%
genre_group.get_group('Crime').head()
# Out:
#     star_rating                     title content_rating  genre  duration  \
# 0           9.3  The Shawshank Redemption              R  Crime       142
# 1           9.2             The Godfather              R  Crime       175
# 2           9.1    The Godfather: Part II              R  Crime       200
# 4           8.9              Pulp Fiction              R  Crime       154
# 21          8.7               City of God              R  Crime       130
#
#                                           actors_list  weekday
# 0   [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...      142
# 1     [u'Marlon Brando', u'Al Pacino', u'James Caan']      175
# 2   [u'Al Pacino', u'Robert De Niro', u'Robert Duv...      200
# 4   [u'John Travolta', u'Uma Thurman', u'Samuel L....      154
# 21  [u'Alexandre Rodrigues', u'Matheus Nachtergael...      130

# %%
genre_group.aggregate('mean')
# Out:
#            star_rating    duration     weekday
# genre
# Action        7.884559  126.485294  126.485294
# Adventure     7.933333  134.840000  134.840000
# Animation     7.914516   96.596774   96.596774
# Biography     7.862338  131.844156  131.844156
# Comedy        7.822436  107.602564  107.602564
# Crime         7.916935  122.298387  122.298387
# Drama         7.902518  126.539568  126.539568
# Family        7.850000  107.500000  107.500000
# Fantasy       7.700000  112.000000  112.000000
# Film-Noir     8.033333   97.333333   97.333333
# History       8.000000   66.000000   66.000000
# Horror        7.806897  102.517241  102.517241
# Mystery       7.975000  115.625000  115.625000
# Sci-Fi        7.920000  109.000000  109.000000
# Thriller      7.680000  114.200000  114.200000
# Western       8.255556  136.666667  136.666667

# %%
imdb_df['new_duration']=genre_group['duration'].transform(lambda x:x.mean())

# %%
imdb_df.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list  weekday  new_duration
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...      142    122.298387
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']      175    122.298387
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...      200    122.298387
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...      152    126.485294
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....      154    122.298387

# %%
new_imdb_df= genre_group.filter(lambda x: x['duration'].mean()>120)

# %%
new_imdb_df.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list  weekday  new_duration
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...      142    122.298387
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']      175    122.298387
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...      200    122.298387
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...      152    126.485294
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....      154    122.298387

# %%
bikes_df['weekday']=bikes_df.index

# %%
weekday_group=bikes_df.groupby('weekday')

# %%
weeday_count=weekday_group.aggregate(sum)
weeday_count.head()
# Out:
#          Rachel / Papineau  Berri1  Maisonneuve_2  Maisonneuve_1  Brébeuf  \
# weekday
# 0                       16      35             51             38      5.0
# 1                       43      83            153             68     11.0
# 2                       58     135            248            104      2.0
# 3                       61     144            318            116      2.0
# 4                       95     197            330            124      6.0
#
#          Parc  PierDup  CSC (Côte Sainte-Catherine)  Pont_Jacques_Cartier
# weekday
# 0          26       10                            0                  27.0
# 1          53        6                            1                  21.0
# 2          89        3                            2                  15.0
# 3         111        8                            1                  19.0
# 4          97       13                            2                  16.0
